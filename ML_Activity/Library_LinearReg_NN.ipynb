# %% [markdown]
# <a href="https://colab.research.google.com/github/bestgradient/AI-Camp-Summer-2022/blob/main/ML_Activity/Library_LinearReg_NN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
train_data = pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')
data = pd.concat((train_data, test_data), sort=False)

# %% [markdown]
# Preprocessing

# %%
from sklearn.preprocessing import LabelEncoder
for col in range(data.shape[1]):
  encoder = LabelEncoder()
  encoder.fit(data.iloc[:, col])
  data.iloc[:, col] = encoder.transform(data.iloc[:, col])

# %%
#filling Na with mean
data = data.fillna(data.mean())

# %%
data.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# Scaling

# %%
from sklearn.preprocessing import minmax_scale
for col in data.columns:
  data[col] = pd.Series(minmax_scale(data[col]), index=data.index)

# %%
data
# Out:
#             Id  MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  \
# 0     0.000000    0.333333       0.6     0.320312  0.317436     1.0    1.0
# 1     0.000343    0.000000       0.6     0.437500  0.458974     1.0    1.0
# 2     0.000685    0.333333       0.6     0.343750  0.649231     1.0    1.0
# 3     0.001028    0.400000       0.6     0.281250  0.452821     1.0    1.0
# 4     0.001371    0.333333       0.6     0.468750  0.856410     1.0    1.0
# ...        ...         ...       ...          ...       ...     ...    ...
# 1454  0.998629    0.866667       0.8     0.000000  0.011795     1.0    1.0
# 1455  0.998972    0.866667       0.8     0.000000  0.010256     1.0    1.0
# 1456  0.999315    0.000000       0.6     0.945312  0.955385     1.0    1.0
# 1457  0.999657    0.600000       0.6     0.296875  0.558974     1.0    1.0
# 1458  1.000000    0.333333       0.6     0.390625  0.461538     1.0    1.0
#
# ...

# %% [markdown]
# Split the data

# %%
X_train = data[:train_data.shape[0]]
Y_train= X_train.SalePrice
X_test = data[train_data.shape[0]:]
Y_test= X_test.SalePrice

# %%
X_train
# Out:
#             Id  MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  \
# 0     0.000000    0.333333       0.6     0.320312  0.317436     1.0    1.0
# 1     0.000343    0.000000       0.6     0.437500  0.458974     1.0    1.0
# 2     0.000685    0.333333       0.6     0.343750  0.649231     1.0    1.0
# 3     0.001028    0.400000       0.6     0.281250  0.452821     1.0    1.0
# 4     0.001371    0.333333       0.6     0.468750  0.856410     1.0    1.0
# ...        ...         ...       ...          ...       ...     ...    ...
# 1455  0.498629    0.333333       0.6     0.296875  0.256410     1.0    1.0
# 1456  0.498972    0.000000       0.6     0.476562  0.804615     1.0    1.0
# 1457  0.499315    0.400000       0.6     0.328125  0.389231     1.0    1.0
# 1458  0.499657    0.000000       0.6     0.343750  0.469744     1.0    1.0
# 1459  0.500000    0.000000       0.6     0.398438  0.497949     1.0    1.0
#
# ...

# %% [markdown]
# Linear reg function

# %%
print(X_train.shape)
print(Y_train.shape)
w = np.zeros((81,), dtype=int)
print(w.shape)
b = 0
# Out:
# (1460, 81)
# (1460,)
# (81,)

# %%
X_train.drop(['SalePrice'],axis=1,inplace=True)
X_test.drop(['SalePrice'],axis=1,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (1460, 80)
# (1459, 80)

# %%
X_train = X_train.to_numpy()
Y_train = Y_train.to_numpy()
X_test = X_test.to_numpy()
Y_test = Y_test.to_numpy()

# %% [markdown]
# Training using Keras

# %%
#Kera Neural Network Package
from keras.models import Sequential, load_model
from keras.layers.core import Dense, Dropout, Activation
from keras.utils import np_utils
from keras.wrappers.scikit_learn import KerasRegressor

# %%
X_train
# Out:
# array([[0.00000000e+00, 3.33333333e-01, 6.00000000e-01, ...,
#         5.00000000e-01, 8.88888889e-01, 8.00000000e-01],
#        [3.42700480e-04, 0.00000000e+00, 6.00000000e-01, ...,
#         2.50000000e-01, 8.88888889e-01, 8.00000000e-01],
#        [6.85400960e-04, 3.33333333e-01, 6.00000000e-01, ...,
#         5.00000000e-01, 8.88888889e-01, 8.00000000e-01],
#        ...,
#        [4.99314599e-01, 4.00000000e-01, 6.00000000e-01, ...,
#         1.00000000e+00, 8.88888889e-01, 8.00000000e-01],
#        [4.99657300e-01, 0.00000000e+00, 6.00000000e-01, ...,
#         1.00000000e+00, 8.88888889e-01, 8.00000000e-01],
#        [5.00000000e-01, 0.00000000e+00, 6.00000000e-01, ...,
#         5.00000000e-01, 8.88888889e-01, 8.00000000e-01]])

# %%
Y_train
# Out:
# array([0.6214178 , 0.51131222, 0.66666667, ..., 0.79487179, 0.30015083,
#        0.33333333])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam

# %%
model = Sequential()

model.add(Dense(20,activation='relu'))
model.add(Dense(20,activation='relu'))
model.add(Dense(20,activation='relu'))
model.add(Dense(20,activation='relu'))
model.add(Dense(1))

model.compile(optimizer='adam',loss='mse')

# %%
model.fit(x=X_train,y=Y_train,epochs=200)
# Out:
# Epoch 1/200
# 46/46 [==============================] - 1s 2ms/step - loss: 0.0533
# Epoch 2/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0146
# Epoch 3/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0115
# Epoch 4/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0092
# Epoch 5/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0087
# Epoch 6/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0079
# Epoch 7/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0074
# Epoch 8/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 9/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0069
# Epoch 10/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0065
# Epoch 11/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0064
# Epoch 12/200
# ...
